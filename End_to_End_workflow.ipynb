# %% [markdown]
# <a href="https://colab.research.google.com/github/Aizismi/turtlebot4_gpt_project/blob/main/Ene_to_End_workflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install graphviz

import graphviz

# Create a new directed graph
dot = graphviz.Digraph(comment='System Workflow')
dot.attr(rankdir='TB')

# Add nodes
dot.node('User', 'User\n🙋')
dot.node('InputPrompt', 'Input Text Prompting\n🗨️')
dot.node('LLM', 'LLM Processing\n🧠')
dot.node('Validation', 'Validation and Error Checking\n✅')
dot.node('ScriptGen', 'Script Generation\n📜')
dot.node('Robot', 'Robot Action Execution\n🤖')

# Add edges
dot.edge('User', 'InputPrompt', 'Clean the living room')
dot.edge('InputPrompt', 'LLM', 'Process natural language')
dot.edge('LLM', 'Validation', 'Generate command structure')
dot.edge('Validation', 'ScriptGen', 'Validated command')
dot.edge('ScriptGen', 'Robot', 'Execute cleaning routine')
dot.edge('Robot', 'User', 'Cleaning complete')

# Render the graph
dot.render('system_workflow', format='png', cleanup=True)
dot
